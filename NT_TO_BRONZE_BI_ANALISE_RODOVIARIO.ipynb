# %%
import re
import json
import unicodedata
import time
import random
from datetime import datetime, timedelta
import requests
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

spark = SparkSession.builder.getOrCreate()

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8",
    "Referer": "https://████████████/"
}

def slugify(s):
    s = unicodedata.normalize("NFKD", s).encode("ascii", "ignore").decode("ascii")
    return re.sub(r"[^a-zA-Z0-9]+", "-", s.lower()).strip("-")

def gerar_rotas(cidades):
    rotas = []
    for i in range(len(cidades)):
        for j in range(len(cidades)):
            if i != j:
                o, ouf = cidades[i]
                d, duf = cidades[j]
                rotas.append({
                    "origem_url": f"{slugify(o)}-{ouf.lower()}-todos",
                    "destino_url": f"{slugify(d)}-{duf.lower()}-todos"
                })
    return rotas

def fetch_state(url):
    try:
        time.sleep(random.uniform(3.0, 5.0))
        r = requests.get(url, headers=HEADERS, timeout=30)
        r.raise_for_status()
        m = re.search(r'window\.__PRELOADED_STATE__\s*=\s*(\{.*?\})\s*;\s*', r.text, flags=re.DOTALL)
        if m:
            return json.loads(m.group(1))
        return None
    except:
        return None

def extract(state, origem, destino, dt_execucao):
    rows = []
    if not state:
        return rows
    try:
        search_data = state.get("aditionalValueFromBackend", {}).get("search", {}).get("result", {})
        routes = search_data.get("routes", {}).get("departureRoutes") or []
        ts = datetime.now().isoformat()

        for r in routes:
            trips = r.get("tripList", []) or []
            preco = r.get("totalPrice") or r.get("price")
            empresas = list(dict.fromkeys([t.get("company", {}).get("friendlyName") or t.get("companyName") or "N/A" for t in trips]))

            rows.append({
                "origem_url": origem,
                "destino_url": destino,
                "data_consulta": dt_execucao,
                "data_extracao": ts,
                "data_viagem": r.get("initialDepartureDate") or r.get("departureDate"),
                "origem": r.get("initialOriginCity") or r.get("originCity"),
                "destino": r.get("finalDestinationCity") or r.get("destinationCity"),
                "preco": float(preco) if preco else None,
                "empresas_raw": json.dumps(empresas, ensure_ascii=False),
                "assentos_disponiveis_raw": json.dumps([t.get("availableSeats", 0) for t in trips]),
                "raw_data": json.dumps(r, ensure_ascii=False)
            })
    except:
        pass
    return rows

def executar_bronze(n_dias=7):
    cidades = [
        ("Vitoria", "ES"), 
        ("Rio de Janeiro", "RJ"), 
        ("Sao Paulo", "SP"), 
        ("Belo Horizonte", "MG")
    ]
    rotas = gerar_rotas(cidades)
    dados_totais = []
    base = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)

    print(f"Iniciando extração de {len(rotas)} rotas para os próximos {n_dias} dias...")

    for rota in rotas:
        for i in range(n_dias + 1):
            dt_url = (base + timedelta(days=i)).strftime("%d/%m/%Y")
            dt_log = (base + timedelta(days=i)).strftime("%Y-%m-%d")
            url = f"https://████████████/passagens-de-onibus/{rota['origem_url']}-para-{rota['destino_url']}?departureDate={dt_url}"
            
            state = fetch_state(url)
            if state:
                viagens = extract(state, rota["origem_url"], rota["destino_url"], dt_log)
                dados_totais.extend(viagens)

    if dados_totais:
        df = spark.createDataFrame(dados_totais)
        window = Window.partitionBy("origem_url", "destino_url", "data_viagem").orderBy(F.col("data_extracao").desc())
        df_final = df.withColumn("rn", F.row_number().over(window)).filter("rn = 1").drop("rn")
        df_final.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("bronze_passagens")
        print(f"Extração concluída com sucesso. Total de registros: {len(dados_totais)}")
    else:
        print("Nenhum dado coletado.")

executar_bronze(7)

display(spark.table("bronze_passagens").limit(10))
# Out:
# Iniciando extração de 12 rotas para os próximos 7 dias...
# Extração concluída com sucesso. Total de registros: 6708
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>assentos_disponiveis_raw</th><th>data_consulta</th><th>data_extracao</th><th>data_viagem</th><th>destino</th><th>destino_url</th><th>empresas_raw</th><th>origem</th><th>origem_url</th><th>preco</th><th>raw_data</th></tr></thead><tbody><tr><td>[7]</td><td>2026-04-26</td><td>2026-04-26T11:51:04.656274</td><td>2026-04-26T10:20:00-03:00</td><td>Rio de Janeiro</td><td>rio-de-janeiro-rj-todos</td><td>["Util"]</td><td>Belo Horizonte</td><td>belo-horizonte-mg-todos</td><td>109.99</td><td>{"routeConnectionId": "7609e2ed9c15fea6437c338f79c01025_1", "initialOriginCity": "Belo Horizonte", "initialOriginState": "MG", "initialOriginCountry": "BR", "initialOriginStopId": "5F3DFC39B0FDF176C862C76BAE8942D1", "initialOriginName": "Terminal Turístico JK", "initialOriginStopDisplayName": "Terminal Turístico JK, Belo Horizonte - MG", "finalDestinationCity": "Rio de Janeiro", "finalDestinationState": "RJ", "finalDestinationCountry": "BR", "finalDestinationStopId": "858ECB5DC41411E3AB2E00155D12D27A", "finalDestinationName": "Rodoviária Novo Rio", "finalDestinationStopDisplayName": "Rodoviária Novo Rio, Rio de Janeiro - RJ", "initialDepartureDate": "2026-04-26T10:20:00-03:00", "finalArrivalDate": "2026-04-26T18:50:00-03:00", "totalDaysToArrivial": 0, "totalPriceAverage": 0, "totalPrice": 109.99, "discountCampaignTotalPrice": 0, "discountCampaignValue": 0, "discoutCampaignType": null, "discountCampaignShowTag": false, "totalDurationMinutes": 510, "totalConnectionMinutes": 0, "totalTripMinutes": 510, "totalDurationHour": "08:30:00", "totalConnectionHour": "00:00:00", "totalTripHour": "08:30:00", "totalConnectionCount": 0, "totalTripCount": 1, "tripList": [{"routeStopId": "7609e2ed9c15fea6437c338f79c01025", "originCity": "Belo Horizonte", "originState": "MG", "originCountry": "BR", "originStopId": "5F3DFC39B0FDF176C862C76BAE8942D1", "originName": "Terminal Turístico JK", "destinationCity": "Rio de Janeiro", "destinationState": "RJ", "destinationCountry": "BR", "destinationStopId": "858ECB5DC41411E3AB2E00155D12D27A", "destinationName": "Rodoviária Novo Rio", "departureDate": "2026-04-26T10:20:00-03:00", "arrivalDate": "2026-04-26T18:50:00-03:00", "daysToArrivial": 0, "canSell": true, "canCancel": false, "canCancelOnline": false, "cancelationTax": 0.05, "cancelationAdvanceTime": "03:00:00", "class": "SEMI LEITO", "price": 109.99, "priceAverage": 0, "duration": "08:30:00", "waitTimeToNextTrip": "00:00:00", "tripNumber": 1, "originDisplayName": "Terminal Turístico JK, Belo Horizonte - MG", "destinationDisplayName": "Rodoviária Novo Rio, Rio de Janeiro - RJ", "availableSeats": 7, "information": null, "vehicleId": "15326721370", "bpe": true, "busProviderCode": "0", "elderlyFree": false, "routeInTransit": false, "priceAverageDiscountPercentage": 0, "classFriendlyName": "SemiLeito", "company": {"name": "UTIL", "friendlyName": "Util", "slug": "util", "logoUrl": "https://cdnbrasilbybusemails.deonibus.com/NewFrontImages/BusCompaniesFullWidth/UTIL.svg", "id": 23}, "discountCampaignPrice": 0, "discountCampaignValue": 0, "discoutCampaignType": null, "notAllowSeatChoice": false, "purchasesAntecedence": "00:30:00", "ticketWithBenefitsFormAllowed": false, "providerConfigurationId": 1}]}</td></tr><tr><td>[29]</td><td>2026-04-26</td><td>2026-04-26T11:51:04.656274</td><td>2026-04-26T11:00:00-03:00</td><td>Rio de Janeiro</td><td>rio-de-janeiro-rj-todos</td><td>["Cometa"]</td><td>Belo Horizonte</td><td>belo-horizonte-mg-todos</td><td>219.99</td><td>{"routeConnectionId": "63a373fb60703d54d09e8a7d9b465ee8_1", "initialOriginCity": "Belo Horizonte", "initialOriginState": "MG", "initialOriginCountry": "BR", "initialOriginStopId": "858CEBDCC41411E3AB2E00155D12D27A", "initialOriginName": "Terminal Central", "initialOriginStopDisplayName": "Terminal Central, Belo Horizonte - MG", "finalDestinationCity": "Rio de Janeiro", "finalDestinationState": "RJ", "finalDestinat ...
